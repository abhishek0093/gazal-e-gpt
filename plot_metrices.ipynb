# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv("logs_2025-01-12.csv")
display(df)
# Out:
#       step    loss     norm        lr  token_per_sec       time
# 0        0  7.2119  14.7751  0.000007    1915.903164  17.103161
# 1        1  7.0298  14.9628  0.000013    1266.645350  25.869909
# 2        2  6.6526  10.3309  0.000019    1592.692211  20.573969
# 3        3  6.5150   5.9519  0.000025    1273.178101  25.737169
# 4        4  6.2333   4.1984  0.000031     976.940152  33.541461
# ...    ...     ...      ...       ...            ...        ...
# 1283  1283  0.0670   0.3543  0.000060     803.694839  40.771694
# 1284  1284  0.0647   0.3155  0.000060     856.011015  38.279881
# 1285  1285  0.0622   0.2592  0.000060     616.062494  53.189409
# 1286  1286  0.0650   0.2881  0.000060     545.072025  60.116826
# 1287  1287  0.0660   0.2778  0.000060     524.737998  62.446402
#
# [1288 rows x 6 columns]

# %%
for i in range(1, len(df.columns)) : 
    curr_col_name = df.columns[i]
    plt.plot(df['step'], df[curr_col_name])
    plt.title(f"{curr_col_name} VS STEP")
    plt.xlabel("steps")
    plt.ylabel(f"{curr_col_name}")
    plt.show()
